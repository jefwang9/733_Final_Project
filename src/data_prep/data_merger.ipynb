# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
DATA_FOLDER = "../data/raw_mobibikes_data/"
PREFIX = "Mobi_System_Data_"
VERBOSE = True

# %%
test_file = "2017.xlsx"
df = pd.read_excel("../data/" + PREFIX + test_file)

# %%
df.to_csv("../data/" + PREFIX + "2017.csv", compression="zip")

# %%
raw_files = [f for f in listdir(DATA_FOLDER) if isfile(join(DATA_FOLDER, f))]

# %%
y = 2021 # yrs = [2018, 2019, 2020, 2021]

files = [f for f in raw_files if str(y) in f and r'~' not in f]
files.sort()

output_file_name = PREFIX + str(y) + ".csv"

# %%
dfs = []

# Read dataframes of this year
for f in files:
    ext = f.split('.')[1]
    
    if VERBOSE:
        print("Processing " + f + " ...")
    
    if ext == "csv":
        df = pd.read_csv(DATA_FOLDER + f)
    elif ext == "xlsx":
        df = pd.read_excel(DATA_FOLDER + f)
    else:
        raise ValueError

    dfs.append(df)
# Out:
# Processing Mobi_System_Data_2021-01.csv ...
# Processing Mobi_System_Data_2021-02.csv ...
# Processing Mobi_System_Data_2021-03.csv ...
# Processing Mobi_System_Data_2021-04.csv ...
# Processing Mobi_System_Data_2021-05.csv ...
# Processing Mobi_System_Data_2021-06.csv ...
# Processing Mobi_System_Data_2021-07.csv ...

# %%
for df in dfs:
    print(len(df.columns))
# Out:
# 14
# 14
# 14
# 14
# 14
# 14
# 14

# %%
dfs[-2].columns
# Out:
# Index(['Departure', 'Return', 'Bike', 'Departure station', 'Return station',
#        'Membership type', 'Covered distance (m)', 'Duration (sec.)',
#        'Departure temperature (C)', 'Return temperature (C)', 'Departure slot',
#        'Return slot', 'Stopover duration (sec.)', 'Number of stopovers'],
#       dtype='object')

# %%
columns = None

# Clean column names
for df in dfs:
    # Clean jobs
    df.drop(columns=[n for n in df.columns if "slot" in n], inplace=True)
    df.drop(columns=[n for n in df.columns if "Manager" in n], inplace=True)
    
    if columns is None:
        columns = df.columns
    else:
        try:
            assert(len(df.columns) <= len(columns))
        except AssertionError as e:
            print(len(df.columns), df.columns)
            print(len(columns), columns)
            raise e
            
        col_mapper = {a: b for a, b in zip(df.columns, columns)}
        df.rename(columns=col_mapper, inplace=True)

        df.reset_index(inplace=True, drop=True)

# %%
# Perform concatenation
res_df = pd.concat(dfs, ignore_index=True)

# %%
res_df
# Out:
#                Departure            Return    Bike  \
# 0        2021-02-01 0:00   2021-02-01 0:00  1274.0
# 1        2021-02-01 0:00   2021-02-01 0:00  1149.0
# 2        2021-02-01 0:00   2021-02-01 0:00  1950.0
# 3        2021-02-01 0:00   2021-02-01 0:00   304.0
# 4       2021-01-31 23:00  2021-01-31 23:00   591.0
# ...                  ...               ...     ...
# 399767   2021-07-01 0:00   2021-07-01 0:00  1169.0
# 399768   2021-07-01 0:00   2021-07-01 0:00  1892.0
# 399769   2021-07-01 0:00   2021-07-01 0:00   162.0
# 399770   2021-07-01 0:00   2021-07-01 0:00  1997.0
# 399771   2021-07-01 0:00   2021-07-01 0:00  1292.0
#
#                                   Departure station  \
# 0                                0001 10th & Cambie
# 1                           0063 Robson & Granville
# 2        0002 Burrard Station (Melville & Dunsmuir)
# 3                              0096 Nicola & Robson
# 4                               0045 Beach & Hornby
# ...                                             ...
# 399767                            0014 Canada Place
# 399768                         0033 Robson & Denman
# 399769                            0014 Canada Place
# 399770  0103 Stanley Park - Third Beach Parking Lot
# 399771   0002 Burrard Station (Melville & Dunsmuir)
#
#                                Return station        Membership type  \
# 0                            0074 10th & Main               365 Plus
# 1                     0063 Robson & Granville            30 Day Pass
# 2                        0096 Nicola & Robson           365 Standard
# 3                         0032 Comox & Denman  365 Day Founding Plus
# 4                    0161 Alexander & Dunlevy           365 Standard
# ...                                       ...                    ...
# 399767                0063 Robson & Granville                24 Hour
# 399768                    0083 Aquatic Centre           365 Standard
# 399769                0063 Robson & Granville                24 Hour
# 399770                  0207 Alberni & Jervis                24 Hour
# 399771  0254 Grandview Bike Lane & Commercial           365 Standard
#
#         Covered distance (m)  Duration (sec.)  Departure battery voltage (mV)  \
# 0                      951.0              259                            3590
# 1                     2726.0             1200                            3636
# 2                     1139.0              274                            3911
# 3                     2527.0              870                            3985
# 4                     4406.0              882                            3905
# ...                      ...              ...                             ...
# 399767                1196.0              823                            3997
# 399768                1890.0              477                            3924
# 399769                1208.0              870                            3840
# 399770                4418.0             1671                            4045
# 399771                5541.0             1617                            3939
#
#         Return battery voltage (mV)  Departure temperature (C)  \
# 0                              3790                          7
# 1                              3764                          7
# 2                              4047                          8
# 3                              4140                          8
# 4                              4206                          9
# ...                             ...                        ...
# 399767                         4064                         22
# 399768                         4085                         23
# 399769                         3953                         22
# 399770                         4177                         22
# 399771                         4113                         23
#
#         Return temperature (C)  Stopover duration (sec.)  Number of stopovers
# 0                            9                         0                    0
# 1                            5                         0                    0
# 2                           10                         0                    0
# 3                           10                       194                    1
# 4                           10                         0                    0
# ...                        ...                       ...                  ...
# 399767                      22                         0                    0
# 399768                      23                         0                    0
# 399769                      21                         0                    0
# 399770                      24                         0                    0
# 399771                      24                         0                    0
#
# [399772 rows x 14 columns]

# %%
res_df.to_csv("../data/" + output_file_name, compression="zip")
